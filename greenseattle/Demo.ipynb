# %% [markdown]
# ## Hello! Start by downloading the following libraries. ##

# %%
from greenseattle import prepare_nn, feature_projection, model_viz
# import greenseattle
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact
import pandas as pd

# %%
all_data = pd.read_csv('./Data/all_data.csv')

# %% [markdown]
# **List of zipcodes to test**

# %%
zipcodes = list(np.unique(all_data['ZIPCODE'].values))
print(zipcodes)
# Out:
# [98101, 98102, 98103, 98104, 98105, 98106, 98107, 98108, 98109, 98112, 98115, 98116, 98117, 98118, 98119, 98121, 98122, 98125, 98126, 98133, 98134, 98144]

# %% [markdown]
# **Let's try it out!**

# %%
model_viz(98105)
# Out:
# /Users/praizanyanwu/Documents/python/direct/greening_seattle/Prediction/greenseattle/greenseattle.py:111: RuntimeWarning: divide by zero encountered in log
#   ax.plot(list_proportion, np.log(pop_val),
# /Users/praizanyanwu/Documents/python/direct/greening_seattle/Prediction/greenseattle/greenseattle.py:125: RuntimeWarning: divide by zero encountered in log
#   matrix = np.stack((np.log(pop_val), np.log(rack_val),
# array([[          -inf, 1.41147114e+01, 1.40944473e+01, 9.81050000e+04],
#        [          -inf, 1.37906026e+01, 1.41543422e+01, 9.81050000e+04],
#        [1.41100219e+01, 1.41100219e+01, 1.41100219e+01, 9.81050000e+04],
#        [1.48232509e+01, 1.43727778e+01, 1.37469474e+01, 9.81050000e+04],
#        [1.50039447e+01, 1.44709205e+01, 1.39955110e+01, 9.81050000e+04],
#        [1.51289819e+01, 1.44358839e+01, 1.43222950e+01, 9.81050000e+04],
#        [1.51876522e+01, 1.47234126e+01, 1.43862313e+01, 9.81050000e+04],
#        [1.52167898e+01, 1.48073824e+01, 1.43941108e+01, 9.81050000e+04],
#        [1.52338083e+01, 1.47799193e+01, 1.43691871e+01, 9.81050000e+04],
#        [1.52465821e+01, 1.47236044e+01, 1.43454979e+01, 9.81050000e+04],
#        [1.52584489e+01, 1.46820989e+01, 1.43306686e+01, 9.81050000e+04],
#        [1.52699330e+01, 1.46582270e+01, 1.43175403e+01, 9.81050000e+04],
#        [1.52806345e+01, 1.46391112e+01, 1.43037937e+01, 9.81050000e+04],
#        [1.52903497e+01, 1.46183899e+01, 1.42891984e+01, 9.81050000e+04],
#        [1.52992062e+01, 1.45958005e+01, 1.42739429e+01, 9.81050000e+04],
#        [1.53074737e+01, 1.45725008e+01, 1.42582707e+01, 9.81050000e+04],
#        [1.53154260e+01, 1.45492846e+01, 1.42424128e+01, 9.81050000e+04],
#        [1.53232894e+01, 1.45264486e+01, 1.42265740e+01, 9.81050000e+04],
#        [1.53312322e+01, 1.45039997e+01, 1.42109291e+01, 9.81050000e+04],
#        [1.53393617e+01, 1.44818255e+01, 1.41956221e+01, 9.81050000e+04]])
